# %% [markdown]
# ## **`**OPTION-1: EXTRACTION OF TABLES FROM PDF FILE**`**

# %%
# !pip install tabula-py

# %%
import tabula

# %%
file = "/content/Characterization-of-active-edible-films-based-on-citral-essential-oil-alginate-and-pectinMaterials.pdf"
table = tabula.read_pdf(file,pages="all")
table
# Out:
# Got stderr: Jun 24, 2021 1:08:32 PM org.apache.pdfbox.pdmodel.font.PDType1Font <init>
# WARNING: Using fallback font LiberationSans for base font Symbol
# Jun 24, 2021 1:08:32 PM org.apache.pdfbox.pdmodel.font.PDType1Font <init>
# WARNING: Using fallback font LiberationSans for base font ZapfDingbats
# Jun 24, 2021 1:08:32 PM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# WARNING: No Unicode mapping for gid00030 (1) in font MCBCCI+SourceSansRoman-Regular
# Jun 24, 2021 1:08:32 PM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# WARNING: No Unicode mapping for gid00035 (2) in font MCBCCI+SourceSansRoman-Regular
# Jun 24, 2021 1:08:32 PM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# WARNING: No Unicode mapping for gid00032 (3) in font MCBCCI+SourceSansRoman-Regular
# Jun 24, 2021 1:08:32 PM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# WARNING: No Unicode mapping for gid00038 (4) in font MCBCCI+SourceSansRoman-Regular
# ...

# %%
type(table)
# Out:
# list

# %%
len(table)
# Out:
# 4

# %%
table[0]
# Out:
#         Sample Sodium Alginate Pectin  Glycerol  Tween® 20 Citral EO
# 0           SA               2      -       1.5        0.2         -
# 1       SA0.15               2      -       1.5        0.2      0.15
# 2        SA0.3               2      -       1.5        0.2       0.3
# 3           Pe               -      2       1.5        0.2         -
# 4       Pe0.15               -      2       1.5        0.2      0.15
# 5        Pe0.3               -      2       1.5        0.2       0.3
# 6      SA + Pe               1      1       1.5        0.2         -
# 7  SA + Pe0.15               1      1       1.5        0.2      0.15
# 8   SA + Pe0.3               1      1       1.5        0.2       0.3

# %%
table[1]
# Out:
#                Unnamed: 0             Thickness  ...          O E  Unnamed: 20
# 0                  Sample                  (μm)  ...  2 (J/mol K)          GTR
# 1                     NaN                  8 ◦C  ...          NaN          NaN
# 2                      SA  127 ± 13 a 102 ± 1 a  ...       17 (1)          NaN
# 3       SA 112 ± 2 de0.15    111 ± 6 b 94 ± 1 c  ...       16 (1)          NaN
# 4                  SA0.30    110 ± 4 b 70 ± 1 f  ...       21 (1)          NaN
# 5                      Pe   110 ± 5 b 102 ± 1 a  ...       20 (1)          NaN
# 6        Pe 119 ± 1 f0.15  107 ± 1 bc 99 ± 2 ab  ...        8 (1)          NaN
# 7                 Pe 0.30     94 ± 9 c 84 ± 2 d  ...       19 (1)          NaN
# 8                 SA + Pe   101 ± 3 bc 98 ± 1 b  ...       24 (1)          NaN
# 9   SA + Pe 165 ± 1 f0.15   104 ± 1 bc 75 ± 1 e  ...     27 (0.9)          NaN
# 10           SA + Pe 0.30    104 ± 5 bc84 ± 1 d  ...     44 (0.9)          NaN
#
# [11 rows x 26 columns]

# %%
table[2]
# Out:
#     Unnamed: 0  Unnamed: 1  ...                 SA+Pe  Unnamed: 12
# 0         5.50         NaN  ...  SA+Peln(GT0R.1 5CO2)   ln(GTR O2)
# 1          NaN         NaN  ...             SA+Pe0.30          NaN
# 2         5.20         NaN  ...                   NaN          NaN
# 3          NaN         NaN  ...                   NaN          NaN
# 4         4.90         NaN  ...                   NaN          NaN
# 5         4.60         NaN  ...                   NaN          NaN
# 6         4.30         NaN  ...                   NaN          NaN
# 7         4.00         NaN  ...                   NaN          NaN
# 8         3.36         3.4  ...             3.52 3.56          NaN
# 9          NaN         NaN  ...                   NaN          NaN
# 10        5.80         NaN  ...                   NaN          NaN
# 11         NaN         NaN  ...                 SA+Pe          NaN
# 12        5.50         NaN  ...             SA+Pe0.15          NaN
# ...

# %%
table[3]
# Out:
#                                            Unnamed: 0  ... Unnamed: 1
# 0                                              Sample  ...        NaN
# 1                                                 NaN  ...        NaN
# 2                                                  SA  ...        NaN
# 3                                             SA 0.15  ...         cd
# 4                                   SA 955 ± 74 b0.30  ...        NaN
# 5                                                  Pe  ...        NaN
# 6                                             Pe 0.15  ...         de
# 7                                             Pe 0.30  ...         de
# 8                                             Pe + SA  ...        NaN
# 9                                        Pe + SA 0.15  ...        NaN
# 10                                        PE + SA0.30  ...        NaN
# 11  lues with different letters within the same co...  ...        NaN
# ...

# %% [markdown]
# **OPTION-2: EXTRACTING TABLES AND STORING IN CSV FILE**

# %%
import tabula

# Read pdf into list of DataFrame
df = tabula.read_pdf("Characterization-of-active-edible-films-based-on-citral-essential-oil-alginate-and-pectinMaterials.pdf", pages='all')


# convert PDF into CSV file
tabula.convert_into("Characterization-of-active-edible-films-based-on-citral-essential-oil-alginate-and-pectinMaterials.pdf", "output.csv", output_format="csv", pages='all')
# Out:
# Got stderr: Jun 24, 2021 1:13:03 PM org.apache.pdfbox.pdmodel.font.PDType1Font <init>
# WARNING: Using fallback font LiberationSans for base font Symbol
# Jun 24, 2021 1:13:03 PM org.apache.pdfbox.pdmodel.font.PDType1Font <init>
# WARNING: Using fallback font LiberationSans for base font ZapfDingbats
# Jun 24, 2021 1:13:03 PM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# WARNING: No Unicode mapping for gid00030 (1) in font MCBCCI+SourceSansRoman-Regular
# Jun 24, 2021 1:13:03 PM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# WARNING: No Unicode mapping for gid00035 (2) in font MCBCCI+SourceSansRoman-Regular
# Jun 24, 2021 1:13:03 PM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# WARNING: No Unicode mapping for gid00032 (3) in font MCBCCI+SourceSansRoman-Regular
# Jun 24, 2021 1:13:03 PM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# WARNING: No Unicode mapping for gid00038 (4) in font MCBCCI+SourceSansRoman-Regular
# ...

# %% [markdown]
# **OPTION 3: CLEANING THE NAN VALUES AND STORING IN XLSX FILE**

# %%
import tabula
file = "/content/Characterization-of-active-edible-films-based-on-citral-essential-oil-alginate-and-pectinMaterials.pdf"
table = tabula.read_pdf(file,pages="all")
# Out:
# Got stderr: Jun 24, 2021 1:13:31 PM org.apache.pdfbox.pdmodel.font.PDType1Font <init>
# WARNING: Using fallback font LiberationSans for base font Symbol
# Jun 24, 2021 1:13:31 PM org.apache.pdfbox.pdmodel.font.PDType1Font <init>
# WARNING: Using fallback font LiberationSans for base font ZapfDingbats
# Jun 24, 2021 1:13:31 PM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# WARNING: No Unicode mapping for gid00030 (1) in font MCBCCI+SourceSansRoman-Regular
# Jun 24, 2021 1:13:31 PM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# WARNING: No Unicode mapping for gid00035 (2) in font MCBCCI+SourceSansRoman-Regular
# Jun 24, 2021 1:13:31 PM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# WARNING: No Unicode mapping for gid00032 (3) in font MCBCCI+SourceSansRoman-Regular
# Jun 24, 2021 1:13:31 PM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# WARNING: No Unicode mapping for gid00038 (4) in font MCBCCI+SourceSansRoman-Regular
# ...

# %%
table[3].head(10)
# Out:
#           Unnamed: 0                     E σy  ...         ε Unnamed: 1
# 0             Sample                      NaN  ...         b        NaN
# 1                NaN              (MPa) (MPa)  ...       (%)        NaN
# 2                 SA      526 ± 52 c 14 ± 1 d  ...  30 ± 1 b        NaN
# 3            SA 0.15    1102 ± 68 ab 24 ± 2 b  ...    24 ± 5         cd
# 4  SA 955 ± 74 b0.30                  17 ± 5c  ...  30 ± 3 b        NaN
# 5                 Pe     492 ± 51 c 13 ± 1 de  ...  18 ± 2 e        NaN
# 6            Pe 0.15  1120 ± 112 ab 21 ± 2 bc  ...    20 ± 1         de
# 7            Pe 0.30    1338 ± 115 a 32 ± 5 a  ...    20 ± 2         de
# 8            Pe + SA      173 ± 17 d 11 ± 1 e  ...  50 ± 1 a        NaN
# 9       Pe + SA 0.15       915 ± 109 b19 ± 3c  ...  18 ± 2 e        NaN
#
# [10 rows x 6 columns]

# %%
table[6].columns
# Out:
# Index(['Films', '0 h', 'S. aureus (108 CFU/mL)', 'Unnamed: 0', 'Unnamed: 1',
#        'Unnamed: 2', 'Unnamed: 3', 'E. coli (108 CFU/mL)', 'Unnamed: 4',
#        'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7'],
#       dtype='object')

# %%
table[6].columns = table[6].columns.str.replace('\r', ' ')

# %%
data = table[6].dropna()
data.to_excel('data.xlsx')

# %%
from tabula import read_pdf
from tabulate import tabulate
  
#reads table from pdf file
df = read_pdf("cc.pdf",pages="all") #address of pdf file
print(tabulate(df))
# Out:
# Got stderr: May 23, 2021 6:37:33 PM org.apache.pdfbox.pdmodel.graphics.color.PDICCBased ensureDisplayProfile
# WARNING: ICC profile is Perceptual, ignoring, treating as Display class
# May 23, 2021 6:37:34 PM org.apache.pdfbox.pdmodel.graphics.color.PDICCBased ensureDisplayProfile
# WARNING: ICC profile is Perceptual, ignoring, treating as Display class
# May 23, 2021 6:37:38 PM org.apache.pdfbox.pdmodel.graphics.color.PDICCBased ensureDisplayProfile
# WARNING: ICC profile is Perceptual, ignoring, treating as Display class
# May 23, 2021 6:37:41 PM org.apache.pdfbox.pdmodel.graphics.color.PDICCBased ensureDisplayProfile
# WARNING: ICC profile is Perceptual, ignoring, treating as Display class
# ...

# %% [markdown]
# # New section
